# %% [markdown]
# <a href="https://colab.research.google.com/github/raanianur/Deteksi-berita-Hoax-Watson.ai/blob/main/Cleaning_%26_Balancing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Configuration
DATASETS = '/content/Data_latih.csv'
BALANCER = 500  # Used to add more data to hoax label, change to 0 if you want make the datasets 1:1

# %%
# Open Datasets file
file = pd.read_csv(DATASETS)
file
# Out:
#           ID  label    tanggal  \
# 0         71      1  17-Aug-20
# 1        461      1  17-Jul-20
# 2        495      1  13-Jul-20
# 3        550      1   8-Jul-20
# 4        681      1  24-Jun-20
# ...      ...    ...        ...
# 4226  999287      1  17-Jan-16
# 4227  999472      1  20-Aug-20
# 4228  999501      1  17-Aug-20
# 4229  999848      1  21-Jul-20
# 4230  999860      1  20-Jul-20
#
#                                                   judul  \
# 0     Pemakaian Masker Menyebabkan Penyakit Legionna...
# 1     Instruksi Gubernur Jateng tentang penilangan  ...
# 2     Foto Jim Rohn: Jokowi adalah presiden terbaik ...
# 3     ini bukan politik, tapi kenyataan Pak Jokowi b...
# 4          Foto Kadrun kalo lihat foto ini panas dingin
# ...                                                 ...
# 4226  : KPK Dilarang Membawa Brimob Bersenjata Masuk...
# 4227            Foto pejabat keuangan dibawah palu arit
# 4228  Gambar Denny Siregar Musuh Warga Tasikmalaya d...
# ...

# %%
file = file.sample(frac=1)
file
# Out:
#           ID  label    tanggal  \
# 1473  339021      1   4-Jul-19
# 3851  904286      1   2-Jul-19
# 24      8176      1  15-Sep-15
# 2009  469407      1   9-Nov-19
# 3060  723548      1  30-Sep-19
# ...      ...    ...        ...
# 823   190671      1  19-Dec-19
# 1091  251840      1  28-Feb-18
# 1517  348456      1   4-Dec-18
# 2944  697955      0  21-Mar-20
# 761   177914      0   2-Apr-18
#
#                                                   judul  \
# 1473  Pilpres 2019 Janggal Karena Diumumkan Saat 12 ...
# 3851  Merdeka.com Membuat dan Menayangkan Berita Ada...
# 24    Larangan anti-miras di Minimarket ditiadakan o...
# 2009  Foto korban meninggal karena mendengar musik p...
# 3060  Muncul Pesan #gejayancarirecehan Atasnamakan B...
# ...                                                 ...
# 823   PLN Bantah Meminta Uang untuk Pemasangan Tutup...
# 1091  Kemkominfo Buat Help Desk Registrasi Kartu Pra...
# 1517  Karni Ilyas Dipanggil Istana Presiden Jokowi U...
# ...

# %%
# Balancing Datasets
rslt_val = file[file['label'] == 0]
rslt_val
# Out:
#           ID  label    tanggal  \
# 2397  560973      0  19-Feb-19
# 3795  893103      0   9-Aug-20
# 4188  989052      0   8-Mar-18
# 2067  481619      0  12-Dec-17
# 422    98107      0   1-May-16
# ...      ...    ...        ...
# 884   203427      0  14-Oct-17
# 2858  678047      0  18-Jan-18
# 990   228930      0  24-Nov-16
# 2944  697955      0  21-Mar-20
# 761   177914      0   2-Apr-18
#
#                                                   judul  \
# 2397  Penjelasan terkait Pernyataan Prabowo soal Imp...
# 3795  Metro TV: Mafindo: Perlu Ada Kode Etik Bagi In...
# 4188  Penyebar Hoaks dan Penghina Prabowo dan Habib ...
# 2067        : Jokowi Izinkan WNA Untuk Mendirikan Ormas
# 422   Ahok Minta Warga Luar Batang Wakafkan Tanah un...
# ...                                                 ...
# 884                   Orang Tua Berkelahi di Lippo Mall
# 2858  Zara Zettira : Semua Pemilik Akses Ke Sistem I...
# 990   : Cuitan Di Twitter Karyawan PT Adhi karya Ter...
# ...

# %%
rslt_hoax = file[file['label'] == 1]
rslt_hoax
# Out:
#           ID  label    tanggal  \
# 1473  339021      1   4-Jul-19
# 3851  904286      1   2-Jul-19
# 24      8176      1  15-Sep-15
# 2009  469407      1   9-Nov-19
# 3060  723548      1  30-Sep-19
# ...      ...    ...        ...
# 3900  915445      1  21-Feb-18
# 4095  961871      1  11-May-19
# 823   190671      1  19-Dec-19
# 1091  251840      1  28-Feb-18
# 1517  348456      1   4-Dec-18
#
#                                                   judul  \
# 1473  Pilpres 2019 Janggal Karena Diumumkan Saat 12 ...
# 3851  Merdeka.com Membuat dan Menayangkan Berita Ada...
# 24    Larangan anti-miras di Minimarket ditiadakan o...
# 2009  Foto korban meninggal karena mendengar musik p...
# 3060  Muncul Pesan #gejayancarirecehan Atasnamakan B...
# ...                                                 ...
# 3900  Presiden Jokowi Temui Perwakilan Partai Komuni...
# 4095             Petugas KPPS Bandung Meninggal Diracun
# 823   PLN Bantah Meminta Uang untuk Pemasangan Tutup...
# ...

# %%
rslt_hoax = rslt_hoax[:len(rslt_val)+BALANCER]
rslt_hoax
# Out:
#           ID  label    tanggal  \
# 1473  339021      1   4-Jul-19
# 3851  904286      1   2-Jul-19
# 24      8176      1  15-Sep-15
# 2009  469407      1   9-Nov-19
# 3060  723548      1  30-Sep-19
# ...      ...    ...        ...
# 1626  371584      1   9-Aug-19
# 2079  485296      1   4-Feb-20
# 3133  739344      1  15-Jan-20
# 2442  570726      1  20-Jun-18
# 687   159013      1  19-May-19
#
#                                                   judul  \
# 1473  Pilpres 2019 Janggal Karena Diumumkan Saat 12 ...
# 3851  Merdeka.com Membuat dan Menayangkan Berita Ada...
# 24    Larangan anti-miras di Minimarket ditiadakan o...
# 2009  Foto korban meninggal karena mendengar musik p...
# 3060  Muncul Pesan #gejayancarirecehan Atasnamakan B...
# ...                                                 ...
# 1626  Orang mati hidup kembali di Sampang ternyata p...
# 2079           Virus Corona masuk makanan kalengan Cina
# 3133    Foto hasil buruan singa iran kepada serigala AS
# ...

# %%
# Create a new dataFrame from Balanced Datasets
newDF = rslt_hoax.append(rslt_val)
newDF
# Out:
# <ipython-input-12-46fb9969b045>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newDF = rslt_hoax.append(rslt_val)
#           ID  label    tanggal  \
# 1473  339021      1   4-Jul-19
# 3851  904286      1   2-Jul-19
# 24      8176      1  15-Sep-15
# 2009  469407      1   9-Nov-19
# 3060  723548      1  30-Sep-19
# ...      ...    ...        ...
# 884   203427      0  14-Oct-17
# 2858  678047      0  18-Jan-18
# 990   228930      0  24-Nov-16
# 2944  697955      0  21-Mar-20
# 761   177914      0   2-Apr-18
#
#                                                   judul  \
# 1473  Pilpres 2019 Janggal Karena Diumumkan Saat 12 ...
# 3851  Merdeka.com Membuat dan Menayangkan Berita Ada...
# 24    Larangan anti-miras di Minimarket ditiadakan o...
# 2009  Foto korban meninggal karena mendengar musik p...
# 3060  Muncul Pesan #gejayancarirecehan Atasnamakan B...
# ...

# %%
newDF = newDF.sample(frac=1)
newDF
# Out:
#           ID  label    tanggal  \
# 746   173343      1  22-Apr-20
# 1361  316281      1   4-Sep-18
# 1757  402403      1  18-May-20
# 527   122101      0  27-Jan-17
# 229    51873      1  23-Sep-19
# ...      ...    ...        ...
# 408    93985      0  27-Feb-19
# 366    82939      1  16-May-20
# 2412  563904      1   5-Oct-17
# 2428  567559      1  10-Dec-19
# 761   177914      0   2-Apr-18
#
#                                                   judul  \
# 746   PT. HEBAT milik Kaesang anak Jokowi melalui Ke...
# 1361  Warga cina di tangkap anggota TNI AD karena me...
# 1757  Pemerintah Takkan Umumkan Lagi Kasus Positif C...
# 527                    Anda Pernah Membully Orang Lain?
# 229   Artikel Jokowi Sebut China Akan Bantu Padamkan...
# ...                                                 ...
# 408   Klarifikasi Polres Bogor Terkait Pembuatan SIM...
# 366   Anak 10 Tahun Meninggal dan Tidak Bisa Keluar ...
# 2412  Tulisan Yusril Ihza Mahendra Tentang Masa Depa...
# ...

# %%
newDF.to_csv('data_cleaned.csv', index=False)
